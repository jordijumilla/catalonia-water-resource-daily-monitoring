# %%
import pandas as pd

df = pd.read_csv('data/aggregated/date/reservoir_sensors_reads.csv')
df
# Out:
#      CALC000041  CALC000046  CALC000103  CALC000120  CALC000125  CALC000143  \
# 0      71.70435    31.38015     1.75850    12.81500     7.79500    79.57425
# 1      71.71910    31.34700     1.75775    12.74900     7.79100    83.00400
# 2      71.65910    31.33215     1.75560    12.66450     7.78200    85.01955
# 3      51.54400    31.26260     1.75450    12.60350     7.77800    86.26575
# 4      61.75660    31.26755     1.75335    12.51875     7.77240    78.60940
# ..          ...         ...         ...         ...         ...         ...
# 805   100.56280    64.42100     1.94520    53.49150    24.07100    82.01180
# 806   100.60420    64.61000     1.96575    53.90025    24.20540    82.51555
# 807   100.64565    64.78745     1.98240    54.26515    24.31675    83.36330
# 808   100.50535    64.92250     1.99610    54.51210    24.41500    81.54280
# 809   100.06010    65.05750     2.00395    54.78850    24.50675    80.53895
#
# ...

# %%
df_pantans = pd.read_csv('data/simplified/metadata/reservoir_sensors_metadata.csv')
df_pantans
# Out:
#      sensor_id                  description dataType  \
# 0   CALC000041  Percentage reservoir volume   NUMBER
# 1   CALC000046  Percentage reservoir volume   NUMBER
# 2   CALC000103  Percentage reservoir volume   NUMBER
# 3   CALC000120  Percentage reservoir volume   NUMBER
# 4   CALC000125  Percentage reservoir volume   NUMBER
# 5   CALC000143  Percentage reservoir volume   NUMBER
# 6   CALC000152  Percentage reservoir volume   NUMBER
# 7   CALC000713  Percentage reservoir volume   NUMBER
# 8   CALC000722  Percentage reservoir volume   NUMBER
# 9   CALC000735  Percentage reservoir volume   NUMBER
# 10  CALC000168  Percentage reservoir volume   NUMBER
#
#                     location  type unit timeZone  publicAccess   component  \
# 0   41.255617318 1.651034658    39    %      CET          True  080581-002
# 1   42.340588782 2.833225165    39    %      CET          True  170600-001
# 2   41.195224935 1.327889195    39    %      CET          True  430430-001
# ...

# %%
dates = df["timestamp"].astype("datetime64[ns]").dt.date.to_list()
dates[-1]
# Out:
# datetime.date(2025, 4, 8)

# %%
sensor_id = df_pantans['sensor_id']
pantans = df_pantans['componentDesc']
